# %% [markdown]
# <a href="https://colab.research.google.com/github/linyuan88/hello-world/blob/master/Hello_World_Colab_Research_Google_com.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 检查GPU是否可用 (Runtime => Change Runtime Type => T4 GPU => Save)

# %%
import torch

# %%
print(torch.cuda.get_device_name(0))
# Out:
# Tesla T4

# %% [markdown]
# 挂载Google Drive存数据(然后去左边菜单 Files 查看 drive/MyDrive/Colab Notebooks 文件夹）

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 安装第三方库

# %%
# !pip install transformers

# %%
# !pip install accelerate
